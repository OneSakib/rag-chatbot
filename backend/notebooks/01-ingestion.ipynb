# %%
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings
from langchain_core.documents import Document
from dotenv import load_dotenv

load_dotenv()

embeddings = OpenAIEmbeddings(
    model="text-embedding-3-small"
)

vector_store = Chroma(
    collection_name="test_collection",
    embedding_function=embeddings,
    persist_directory="/app/db",
)

docs = [
    Document(page_content="Hello world"),
    Document(page_content="This is a test document"),
]

docs
# Out:
# [Document(metadata={}, page_content='Hello world'),
#  Document(metadata={}, page_content='This is a test document')]

# %%
print("BEFORE ADD", flush=True)

ids = vector_store.add_documents(docs)

print("AFTER ADD", ids, flush=True)
# Out:
# BEFORE ADD
# AFTER ADD ['02f9e850-b817-40de-8e89-fea912c1eef1', '1ce6961f-1c2a-427e-bf5d-3dc1ffec46c5']

# %%
vector_store.similarity_search("hello",k=1)
# Out:
# [Document(id='02f9e850-b817-40de-8e89-fea912c1eef1', metadata={}, page_content='Hello world')]
